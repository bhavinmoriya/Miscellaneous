# %% [markdown]
# <a href="https://www.kaggle.com/code/bhavinmoriya/ross-sheldon-a-first-course-in-probability?scriptVersionId=127845151" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# We shall be discussing a book called : A First course in Probability by R Sheldon.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from itertools import permutations
from scipy.special import binom
from collections import Counter
from numpy.random import choice

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# A communication system
# is to consist of n seemingly identical antennas that are to be lined up in a linear order.
# The resulting system will then be able to receive all incoming signals—and will be
# called functional—as long as no two consecutive antennas are defective. If it turns
# out that exactly m of the n antennas are defective, what is the probability that the
# resulting system will be functional?

# %%
# As there are 6 ways one can arrange 1 (not defective) and 0 (defective), and there are 3 ways which avoids consecutive zeros
# we get prob of functional netwark would be 3/ 6.
n, m = 4,2
def functional(m, n):
    antennas = [0 for i in range(m)] + [1 for i in range(n-m)]
    network = set(permutations(antennas))
    failure = 0
    
    for i in network:
        for j in range(len(i)-1):
            if [i[j], i[j+1]] == [0,0]:
                failure += 1
#                 print(i)
                break
            
    k = len(network)
#     print(k, failure)
    return  (k - failure)/ k

# %%
for i in range(4,10):
    for j in range(2,int(np.ceil(i/2))+1):
        print(f'No. of Antennas, defective, Probability of functional: {i,j, functional(j,i), binom(i - j + 1, j) / binom(i,j)}')
# Out:
# No. of Antennas, defective, Probability of functional: (4, 2, 0.5, 0.5)
# No. of Antennas, defective, Probability of functional: (5, 2, 0.6, 0.6)
# No. of Antennas, defective, Probability of functional: (5, 3, 0.1, 0.1)
# No. of Antennas, defective, Probability of functional: (6, 2, 0.6666666666666666, 0.6666666666666666)
# No. of Antennas, defective, Probability of functional: (6, 3, 0.2, 0.2)
# No. of Antennas, defective, Probability of functional: (7, 2, 0.7142857142857143, 0.7142857142857143)
# No. of Antennas, defective, Probability of functional: (7, 3, 0.2857142857142857, 0.2857142857142857)
# No. of Antennas, defective, Probability of functional: (7, 4, 0.02857142857142857, 0.02857142857142857)
# No. of Antennas, defective, Probability of functional: (8, 2, 0.75, 0.75)
# No. of Antennas, defective, Probability of functional: (8, 3, 0.35714285714285715, 0.35714285714285715)
# No. of Antennas, defective, Probability of functional: (8, 4, 0.07142857142857142, 0.07142857142857142)
# No. of Antennas, defective, Probability of functional: (9, 2, 0.7777777777777778, 0.7777777777777778)
# No. of Antennas, defective, Probability of functional: (9, 3, 0.4166666666666667, 0.4166666666666667)
# No. of Antennas, defective, Probability of functional: (9, 4, 0.11904761904761904, 0.11904761904761904)
# No. of Antennas, defective, Probability of functional: (9, 5, 0.007936507936507936, 0.007936507936507936)

# %% [markdown]
# A poker hand consists of 5 cards. If the cards have distinct consecutive values and
# are not all of the same suit, we say that the hand is a straight. For instance, a hand
# consisting of the five of spades, six of spades, seven of spades, eight of spades, and
# nine of hearts is a straight. What is the probability that one is dealt a straight?

# %%
colors = ['clubs' , 'diamonds' , 'hearts', 'spades']

def draw():

    # np.random.choice(colors,size=5)
    return list(zip(np.random.choice(range(1,14),size=5), np.random.choice(colors,size=5)))

d = draw()
d
# Out:
# [(1, 'hearts'), (6, 'clubs'), (8, 'hearts'), (9, 'hearts'), (11, 'clubs')]

# %%
def is_straight(draw):
    if len(set([i[1] for i in draw])) == 1:
        return False
    else:
        nums = np.sort([i[0] for i in draw])
        return np.all(nums == np.array(num[0]+i for i in range(5)))
is_straight(d)
# Out:
# False

# %%
# monte carlo simulation
n = 100_000
count = 0
for i in range(n):
    d = draw()
    if is_straight(d):
        count += 1
print(count/n)
# Out:
# 0.0

# %% [markdown]
# Probability of getting straight is about .0039 which is very low and hence we may not get answer without iterating more (which is heavy on the machine).

# %%
'''A 5-card poker hand is said to be a full house if it consists of 3 cards of the same
denomination and 2 other cards of the same denomination (of course, different from
the first denomination). Thus, a full house is three of a kind plus a pair. What is the
probability that one is dealt a full house?'''

def full_house(draw):
    return set(Counter([i[0] for i in draw]).values()) == {3,2}
d = draw()
full_house(d)
# Out:
# False

# %% [markdown]
# In the game of bridge, the entire deck of 52 cards is dealt out to 4 players. What is
# the probability that each player receives 1 ace?

# %%
n = 100_000
count = 0
for i in range(n):
    d = np.random.choice([i%13 for i in range(52)], replace=False, size=52).reshape(4,13)
    
#     print(np.random.randint(0,13,size=(4,13)))
#     0 in draw[0]
    if np.all([0 in d[j] for j in range(4)]):
#         print(draw)
        count += 1
#         print(draw,'\n',i)
#     np.all([0 is in i[j]])
print(f'Probability that each player receives 1 ace is : {count/n}')
# Out:
# Probability that each player receives 1 ace is : 0.10599

# %%
n = 100_000
count = 0
for i in range(n):
    d = draw()
    
#     print(np.random.randint(0,13,size=(4,13)))
#     0 in draw[0]
    if full_house(d):
#         print(draw)
        count += 1
#         print(draw,'\n',i)
#     np.all([0 is in i[j]])
print(f'Probability of full house is  : {count/n}')
# Out:
# Probability of full house is  : 0.00409

# %% [markdown]
# Probability of full house is  : .0014

# %%
earn = 0
for i in range(n):
    earn += np.random.choice(range(1,7))
earn / n
# Out:
# 3.49856

# %% [markdown]
# Suppose that our experiment consists of tossing 3 fair coins. If we let Y denote the
# number of heads that appear, then Y is a random variable taking on one of the values
# 0, 1, 2, and 3 with respective probabilities

# %%
from collections import Counter

# %%
coin = list('HT')
# choice(coin,size=23)
n = 100_000
for i in range(4): # i = no. of heads
    count = 0
    j = 0
    while j < n:
        toss = choice(coin,size=3)
        if Counter(toss)['H'] == i:
            count +=1
        j += 1
    
    print(f'Getting {i} heads in 3 toss, has probability {count/n}')
# Out:
# Getting 0 heads in 3 toss, has probability 0.12487
# Getting 1 heads in 3 toss, has probability 0.37686
# Getting 2 heads in 3 toss, has probability 0.37824
# Getting 3 heads in 3 toss, has probability 0.12458

# %% [markdown]
# Four balls are to be randomly selected, without replacement, from an urn that con-
# tains 20 balls numbered 1 through 20. If X is the largest numbered ball selected, then
# X is a random variable that takes on one of the values 4, 5, . . . , 20. Find out the P(X=i) for each i.

# %%
balls = [i for i in range(1,21)]
choice(balls,4,replace=False)
n = 10_000
for i in range(4,21):
    j = 0
    count = 0
    while j < n:
        if choice(balls,4,replace=False).max() == i:
            count += 1
        j += 1
    print(f'Probability of X={i} by simulation and by formula are : {count/n, binom(i-1,3)/binom(20,4)} respectively')
# Out:
# Probability of X=4 by simulation and by formula are : (0.0002, 0.0002063983488132095) respectively
# Probability of X=5 by simulation and by formula are : (0.0006, 0.000825593395252838) respectively
# Probability of X=6 by simulation and by formula are : (0.0026, 0.0020639834881320948) respectively
# Probability of X=7 by simulation and by formula are : (0.0047, 0.0041279669762641896) respectively
# Probability of X=8 by simulation and by formula are : (0.0076, 0.007223942208462332) respectively
# Probability of X=9 by simulation and by formula are : (0.0121, 0.011558307533539732) respectively
# Probability of X=10 by simulation and by formula are : (0.0194, 0.0173374613003096) respectively
# Probability of X=11 by simulation and by formula are : (0.0242, 0.02476780185758514) respectively
# Probability of X=12 by simulation and by formula are : (0.0319, 0.034055727554179564) respectively
# Probability of X=13 by simulation and by formula are : (0.0453, 0.04540763673890609) respectively
# Probability of X=14 by simulation and by formula are : (0.0613, 0.059029927760577916) respectively
# Probability of X=15 by simulation and by formula are : (0.0715, 0.07512899896800826) respectively
# Probability of X=16 by simulation and by formula are : (0.0928, 0.09391124871001032) respectively
# Probability of X=17 by simulation and by formula are : (0.115, 0.11558307533539731) respectively
# Probability of X=18 by simulation and by formula are : (0.1431, 0.14035087719298245) respectively
# Probability of X=19 by simulation and by formula are : (0.1728, 0.16842105263157894) respectively
# Probability of X=20 by simulation and by formula are : (0.2024, 0.2) respectively

# %% [markdown]
# Independent trials consisting of the flipping of a coin having probability p of coming
# up heads are continually performed until either a head occurs or a total of n flips is
# made. If we let X denote the number of times the coin is flipped, then X is a random
# variable taking on one of the values 1, 2, 3, . . . , n with respective probabilities

# %%
coin = list('HT')
n = 10000
p = .5
for i in range(1,11): # we shall take n=10 (dont confuse this n with the iteration n)
    count = 0
    j = 0
    if i == 1:
        while j < n:
            result = choice(coin,i, p=[p, 1-p])
    #         print(result.shape[0])
            if (result[-1] == 'H'):
                count += 1

            j += 1
        print(f'Probability of X= {i} by (Simulation, Formulas) are : {count/n, (p)}')    
    elif i < 10 and i > 1:
        while j < n:
            result = choice(coin,i, p=[p, 1-p])
    #         print(result.shape[0])
            if (result[-1] == 'H') and (set(result[:-1])=={'T'}):
                count += 1

            j += 1
        print(f'Probability of X= {i} by (Simulation, Formulas) are : {count/n, (p)*((1-p)**(i-1))}')
    else:
        while j < n:
            result = choice(coin,i, p=[p, 1-p])
    #         print(result.shape[0])
            if (set(result[:-1])=={'T'}):
                count += 1

            j += 1
        print(f'Probability of X= {i} by (Simulation, Formulas) are : {count/n, ((1-p)**(i-1))}')
               
#     if i < 10 and i > 1:
#         print(f'Probability of X= {i} by (Simulation, Formulas) are : {count/n, (p)*((1-p)**(i-1))}')
#     elif i == 1:
#         print(f'Probability of X= {i} by (Simulation, Formulas) are : {count/n, (p)}')
#     else:
#         print(f'Probability of X= {i} by (Simulation, Formulas) are : {count/n, ((1-p)**(i-1))}')
# Out:
# Probability of X= 1 by (Simulation, Formulas) are : (0.5007, 0.5)
# Probability of X= 2 by (Simulation, Formulas) are : (0.2467, 0.25)
# Probability of X= 3 by (Simulation, Formulas) are : (0.1218, 0.125)
# Probability of X= 4 by (Simulation, Formulas) are : (0.0671, 0.0625)
# Probability of X= 5 by (Simulation, Formulas) are : (0.035, 0.03125)
# Probability of X= 6 by (Simulation, Formulas) are : (0.0151, 0.015625)
# Probability of X= 7 by (Simulation, Formulas) are : (0.007, 0.0078125)
# Probability of X= 8 by (Simulation, Formulas) are : (0.0051, 0.00390625)
# Probability of X= 9 by (Simulation, Formulas) are : (0.0024, 0.001953125)
# Probability of X= 10 by (Simulation, Formulas) are : (0.0017, 0.001953125)
